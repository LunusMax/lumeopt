# %% [markdown]
# **ACESSO AO DRIVE:**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# IMPORTAÇÃO DE MÓDULOS:

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import os

# %% [markdown]
# **ACESSO LUCIO:**

# %%
# Caminho base onde os arquivos estão armazenados
base_path = '/content/drive/My Drive/Master/Players/'


# Caminho base para salvar os arquivos tratados
output_base_path = '/content/drive/My Drive/Master/Players_Transposed/'

# %% [markdown]
# **ACESSO DILSON:**

# %%
# Caminho base onde os arquivos estão armazenados
base_path = '/content/drive/My Drive/Lucio_compartilhado/Players/'

# Caminho base para salvar os arquivos tratados
output_base_path = '/content/drive/My Drive/Lucio_compartilhado/Players_Transposed/'

# %% [markdown]
# **ACESSO AOS ARQUIVOS:**

# %%
# Verificar e criar a pasta de saída se não existir
if not os.path.exists(output_base_path):
    os.makedirs(output_base_path)

# Sufixos das temporadas
season_suffixes = ['2023-2024', '2022-2023', '2021-2022', '2020-2021']

# Lista de times
team_list = [
    'atalanta', 'bologna', 'cagliari', 'cremonese', 'empoli', 'fiorentina',
    'frosinone', 'genoa', 'hellas-verona', 'internazionale', 'juventus',
    'lazio', 'lecce', 'milan', 'monza', 'napoli', 'parma', 'roma',
    'salernitana', 'sampdoria', 'sassuolo', 'spezia', 'torino', 'udinese',
    'venezia'
]

# %% [markdown]
# **PROCESSAMENTO DOS DADOS:**

# %%
# Processar cada arquivo
for team in team_list:
    for season in season_suffixes:
        file_name = f"data_{team}_{season}.csv"
        file_path = os.path.join(base_path, file_name)

        # Verificar se o arquivo existe antes de tentar abri-lo
        if os.path.exists(file_path):
            data = pd.read_csv(file_path)

            # Transpor dados
            transposed_data = data.T.reset_index()

            # Apagar a primeira linha
            new_header = transposed_data.iloc[0]  # Esta é a primeira linha
            transposed_sem_linha_0 = transposed_data[1:]  # Tirar a primeira linha
            transposed_sem_linha_0.columns = new_header  # Definir a primeira linha como cabeçalho

            # Caminho do arquivo de saída
            output_file_path = os.path.join(output_base_path, file_name)

            # Salvar o DataFrame processado
            transposed_sem_linha_0.to_csv(output_file_path, index=False)
            print(f"Arquivo processado e salvo: {output_file_path}")

        else:
            print(f"Arquivo não encontrado: {file_path}")
# Out:
# Arquivo processado e salvo: /content/drive/My Drive/Master/Players_Transposed/data_atalanta_2023-2024.csv
# Arquivo processado e salvo: /content/drive/My Drive/Master/Players_Transposed/data_atalanta_2022-2023.csv
# Arquivo processado e salvo: /content/drive/My Drive/Master/Players_Transposed/data_atalanta_2021-2022.csv
# Arquivo processado e salvo: /content/drive/My Drive/Master/Players_Transposed/data_atalanta_2020-2021.csv
# Arquivo processado e salvo: /content/drive/My Drive/Master/Players_Transposed/data_bologna_2023-2024.csv
# Arquivo processado e salvo: /content/drive/My Drive/Master/Players_Transposed/data_bologna_2022-2023.csv
# Arquivo processado e salvo: /content/drive/My Drive/Master/Players_Transposed/data_bologna_2021-2022.csv
# Arquivo processado e salvo: /content/drive/My Drive/Master/Players_Transposed/data_bologna_2020-2021.csv
# Arquivo processado e salvo: /content/drive/My Drive/Master/Players_Transposed/data